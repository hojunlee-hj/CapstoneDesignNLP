# %% [markdown]
# # 02. 데이터 라벨링 산출물 분석 - 시각화
# - 긍정으로 라벨링된 df_positive
#   - Dataframe 구조 확인
#   - 긍정 비율 확인
# - 부정으로 라벨링된 df_negative
#   - Dataframe 구조 확인
#   - 부정 비율 확인
#   - 클래스별 분포 확인
#   - 범위별 분포 확인

# %% [markdown]
# ## 1. 데이터셋 로드

# %%
import numpy as np
import pandas as pd

valid_class = ['0', '1', '2', '3', '4', '5']
filepath = '../data/Dataset_221127.csv'
dataset = pd.read_csv(filepath, index_col = 'id')

# 현재 0~12500, 14001~ 까지 라벨링됨
# 라벨링 다 되면 df_labeled = dataset
df_labeled = pd.merge(dataset.iloc[0:12500], dataset.iloc[14001:], how='outer')
df_positive = df_labeled[(df_labeled["label"] == 1) & (df_labeled["label2"] == '-1')]
df_negative = df_labeled[(df_labeled["label"] == 0) & (df_labeled["label2"].isin(valid_class))]

# %% [markdown]
# ### 시각화 라이브러리 로드

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 2. 긍정으로 라벨링된 df_positive 관련 데이터 분석 및 시각화

# %% [markdown]
# ### 2.1 Dataframe 구조 확인¶

# %%
df_positive
# Out:
#                                                 document  label label2
# 20                                 그래도 좋은 앱 만들어주셔서 감사합니다      1     -1
# 24                                                너무 좋네요      1     -1
# 25                                   이번 업데이트 아주 맘에 들어요 ㅠ      1     -1
# 26     그동안 플레이리스트 편집하려면 너무 귀찮았고 새 곡 추가해도 앨범 다시 열어줘야 했...      1     -1
# 27                                          진짜 최고 편해요 ㅠㅠ      1     -1
# ...                                                  ...    ...    ...
# 20745                               지니 뮤직으로 음악 잘 듣고 있습니다      1     -1
# 20759                       음악을 검색하면 바로 음악을 들을 수 있어서 좋아요      1     -1
# 20760                    업데이트 한 후 기타 미디어 재생 시 노래가 끊기지 않음      1     -1
# 20800                                         노래 잘듣고있습니다      1     -1
# 20801              아기 나이가 세 살 미만이라서 2분밖에 못듣지만 잘 쓰고있습니다ㅎㅎ      1     -1
#
# [1756 rows x 3 columns]

# %% [markdown]
# ### 2.2 긍정 비율 확인

# %%
positive_ratio = (len(df_positive) / len(df_labeled)) * 100
print("긍정 비율 : %.4f%%" % positive_ratio)
# Out:
# 긍정 비율 : 8.4366%

# %% [markdown]
# ## 3. 부정으로 라벨링된 df_negative 관련 데이터 분석 및 시각화

# %% [markdown]
# ### 3.1 Dataframe 구조 확인

# %%
df_negative
# Out:
#                                                 document  label label2
# 0                                        몇년간 잘만 쓰고 있었는데요      0      0
# 1                         최근 업뎃이후로 너무 불편해서 리뷰를 다 써보러 와요       0      0
# 2                           업뎃후 적응이야 늘 하는거지만 적당히 바껴야되는데       0      3
# 3      대체 좋아요 랑 댓글 위치까진ㅋㅋㅋㅋㅋ왜 바꾸는건짘ㅋㅋㅋㅠㅠ너무 자주 바뀌는 설정들...      0      0
# 4      군대 전역전까지 메롱쓰다가 년 전역후부터 지니뮤직으로 갈아탄후 계속 사용하고있는 유...      0      3
# ...                                                  ...    ...    ...
# 20809                       그리고 한시간전에 리뷰남겼는데 맘대로 삭제가 됐네요      0      2
# 20810  아니 왜 포인트에 관한게 하나도 안뜨냐 인터넷이랑 공지사항보고 하란대로 다했는데 포...      0      2
# 20811                                       기가지니에서는 끊기네요      0      1
# 20812                                     이제는 노래 재생도 안된다      0      4
# 20813                                    패드에서는 음질이 안 좋아요      0      1
#
# [18975 rows x 3 columns]

# %% [markdown]
# ### 3.2 부정 비율 확인

# %%
negative_ratio = (len(df_negative) / len(df_labeled)) * 100
print("부정 비율 : %.4f%%" % negative_ratio)
# Out:
# 부정 비율 : 91.1646%

# %% [markdown]
# ### 3.3 클래스별 분포 확인

# %%
df_negative["label2"].unique()
# Out:
# array(['0', '3', '1', '2', '4', '5'], dtype=object)

# %%
def plotAsBar(df):
    series=df["label2"].value_counts(sort=False).sort_index() #.drop(['-1', '22'])
    
    y = [series[idx] for idx in range(len(series))]
    x = np.arange(len(y))    
    xlabel = ["단순부정", "앱개발", "서비스개발", "서비스기획", "콘텐츠운영", "IT기획"]
    
    plt.title("클래스 별 부정 라벨링 데이터")
    plt.bar(x, y, width=0.6)
    plt.xticks(x, xlabel)
    # plt.yticks(sorted(y))
    plt.xlabel("클래스", labelpad=10)
    plt.ylabel("부정 리뷰 수", labelpad=10)
    # plt.tick_params(axis='x', which='major', pad=15)
    plt.tick_params(axis='both', which='major', pad = 8)
    plt.rcParams["figure.figsize"] = (8,10)
    plt.show()

# %%
def plotAsPieChart(df):
    series = df["label2"].value_counts(sort=False).sort_index() #.drop(['-1', '22'])
    
    ratio = [series[idx]/len(series) for idx in range(len(series))]
    x = np.arange(len(ratio))    
    xlabel = ["단순부정", "앱 개발팀", "서비스 개발팀", "서비스 기획팀", "콘텐츠 운영팀", "IT 기획팀"]
    wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
    
    plt.title("클래스 별 부정 라벨링 데이터")
    plt.pie(ratio, labels = xlabel, autopct="%.1f%%", startangle=90, wedgeprops=wedgeprops)
    # plt.figure(figsize=(10,10))
    plt.rcParams["figure.figsize"] = (8,10)
    plt.show()

# %%
plotAsBar(df_negative)

# %%
plotAsPieChart(df_negative)

# %% [markdown]
# ### 3.4 범위별 분포 확인

# %% [markdown]
# #### 0~7000 번 부정 라벨 데이터

# %%
df_negative[0:5724]
# Out:
#                                                document  label label2
# 0                                       몇년간 잘만 쓰고 있었는데요      0      0
# 1                        최근 업뎃이후로 너무 불편해서 리뷰를 다 써보러 와요       0      0
# 2                          업뎃후 적응이야 늘 하는거지만 적당히 바껴야되는데       0      3
# 3     대체 좋아요 랑 댓글 위치까진ㅋㅋㅋㅋㅋ왜 바꾸는건짘ㅋㅋㅋㅠㅠ너무 자주 바뀌는 설정들...      0      0
# 4     군대 전역전까지 메롱쓰다가 년 전역후부터 지니뮤직으로 갈아탄후 계속 사용하고있는 유...      0      3
# ...                                                 ...    ...    ...
# 6996  지니 뮤직을 데이터로 재생을 하려고 들어가면 데이터가 원활하지 않아서 재로그인을 하...      0      5
# 6997                          자주 이러는 것 같은데 좀만 신경 써주세요 ㅠ      0      0
# 6998  제 핸드폰이 이상한 줄 알고 다른 것도 다 켜봤는데 지니 뮤직 말고 유튜브나 멜론은...      0      0
# 6999  요금제에 포함이 되어있었는데 갑자기 분듣기가 되어서 봤더니 이번달부터는 포인트로 재...      0      2
# 7000   사용중인 이용권에서는 요금제를 사용중이라고 되어있는데 새벽에 애플에서 원 결제가 됐어요      0      2
#
# [5724 rows x 3 columns]

# %% [markdown]
# #### 7000~ 12500 부정 라벨 데이터 ( 7000 ~ 14000 이 정상범위)

# %%
df_negative[5725:10890]
# Out:
#                                                 document  label label2
# 7002                                           아이폰사용자입니다      0      0
# 7003            폰이 문제인지 앱이 ㅂ문제인지 듣다가 꾾기고 잘 안넘어가고 로딩도 느려요      0      2
# 7004                                          기종은 아이폰입니다      0      0
# 7005   아니 중간중간 멈추고 앱 작동 제대로 안되고 쓰는 사람은 어떻하라구 ㅠㅠ 하 진짜 화딱지      0      1
# 7006                        진짜로 오래썼는데 요즘에 로딩이 너무 길어져요 ㅠㅠ      0      2
# ...                                                  ...    ...    ...
# 12497  까지 지원한다고 해서 리얼팩 원 추가 결제했는데 막상 까지 지원하는 앨범 국내외 합...      0      0
# 12498  이제 서비스 시작이니 이해해 달라고 하기에도 너무 준비된게 없어서 민망할 수준인데 ...      0      2
# 12499  앨범이 빠르게 추가되지 않는다면 소비자를 기만하는 걸로 간주하고 벅스 프리미엄이나 ...      0      0
# 12500                                 제가 열심히 사용을 하고있기는해요      0      0
# 12501  근데 갑자기 얼마전까지 잘되고 있었는데 갑자기 사용을 하다 노래를 다음 노래로 넘기...      0      2
#
# [5165 rows x 3 columns]

# %% [markdown]
# #### 14000 ~ 21000 부정 라벨 데이터

# %%
df_negative[10891:]
# Out:
#                                                 document  label label2
# 12503  저만 그런가요 구글안드로이드오토의 음성명령을 통하면 안드로이드오토는 명확하게 인식했...      0      1
# 12504                다른 경쟁사앱과 비교해보시고 검색 시스템 개선 해주시기 바랍니다      0      0
# 12505  제가 현재 음원사이트 개를 사용하다가 여러 곡의 음질을 비교해보니 지니가 음질이 가...      0      2
# 12508  제가 지금까지 이브 론 스 지니를 사용해 보았는데 다른 건 몰라도 음질은 지니가 최...      0      0
# 12509  노래 자주 즐겨 들으시는 분들에게 투자할 가치가 있으니 추천드립니다 지니 음질 제발...      0      2
# ...                                                  ...    ...    ...
# 20809                       그리고 한시간전에 리뷰남겼는데 맘대로 삭제가 됐네요      0      2
# 20810  아니 왜 포인트에 관한게 하나도 안뜨냐 인터넷이랑 공지사항보고 하란대로 다했는데 포...      0      2
# 20811                                       기가지니에서는 끊기네요      0      1
# 20812                                     이제는 노래 재생도 안된다      0      4
# 20813                                    패드에서는 음질이 안 좋아요      0      1
#
# [8084 rows x 3 columns]

# %%
plotAsPieChart(df_negative[0:5724])

# %%
plotAsPieChart(df_negative[5725:10890])

# %%
plotAsPieChart(df_negative[10891:])
